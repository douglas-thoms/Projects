# %% [markdown]
# # Objective Question V1

# %% [markdown]
# ## Setting Expectations
# ### Objective Questions
# * What is initial objective as you understand it?
# What is the best algorithm to predict meter reading based on variables provided by ASHRAE?
#
# * Type of questions
# Predictive

# %% [markdown]
# ### Other Questions
# * How is accuracy and error measured?

# %% [markdown]
# ## Collecting Information

# %%
from IPython.display import Image
Image(filename = "img/error.calc.png")

# %% [markdown]
# #### Explanation of RMSLE
# https://www.kaggle.com/c/ashrae-energy-prediction/discussion/113064

# %%
Image(filename = "img/error.expln.png")

# %%
Image(filename = "img/error.expln2.png")

# %%
# RMSLE calc
import math

def rmsle(y, y_pred):     
    assert len(y) == len(y_pred)
    terms_to_sum = [(math.log(y_pred[i] + 1) - math.log(y[i] + 1)) ** 2.0 for i,pred in enumerate(y_pred)]
    return (sum(terms_to_sum) * (1.0/len(y))) ** 0.5

# %%
from sklearn.metrics import mean_squared_log_error
np.sqrt(mean_squared_log_error( y_test, predictions ))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-62d487b5607f> in <module>
#       1 from sklearn.metrics import mean_squared_log_error
# ----> 2 np.sqrt(mean_squared_log_error( y_test, predictions ))
#
# NameError: name 'np' is not defined

# %% [markdown]
# ## Adjusting Explanations
# * None needed
