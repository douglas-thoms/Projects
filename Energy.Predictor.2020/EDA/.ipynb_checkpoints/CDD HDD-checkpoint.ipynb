# %%
import pandas as pd
import seaborn as sns
import gc
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
test = pd.read_csv("../data/df_samp.csv")

# %%
sample = test[['meter_reading','square_feet','air_temperature','primary_use','meter']].head(400000)

# %%
sample.shape
# Out:
# (400000, 5)

# %%
sample.head()
# Out:
#    meter_reading  square_feet  air_temperature          primary_use  \
# 0       1857.260       121074             12.8            Education
# 1       1097.470        61904             12.8            Education
# 2        337.683        16726             12.8               Office
# 3       1266.310       200933             12.8  Lodging/residential
# 4        337.683        21657             12.8            Education
#
#           meter
# 0  chilledwater
# 1  chilledwater
# 2  chilledwater
# 3  chilledwater
# 4  chilledwater

# %%
sns.lmplot(x='air_temperature',y='meter_reading',data=sample)

# %%
k = sns.relplot(x="air_temperature", y="meter_reading",
                 col="primary_use",
                 row='meter',
                 kind="scatter", data=sample)

# %%
def HDD(x):
    dd = 18-x
    if dd>0:
        return dd
    else:
        return 0

# %%
sample['HDD']=sample['air_temperature'].apply(lambda x: HDD(x))
sample[sample.HDD==0]
# Out:
#         meter_reading  square_feet  air_temperature          primary_use  \
# 30          3461.2500       121074             21.1            Education
# 31          1983.8900        61904             21.1            Education
# 32           464.3140        16726             21.1               Office
# 33          2828.0900       200933             21.1  Lodging/residential
# 34           590.9450        21657             21.1            Education
# ...               ...          ...              ...                  ...
# 399995        31.3703         9703             27.2               Office
# 399996        68.7800       102856             27.2      Public services
# 399997       206.7910       102856             27.2      Public services
# 399998        67.2300        60086             27.2  Lodging/residential
# 399999        97.8036        60086             27.2  Lodging/residential
#
#                meter  HDD
# 30      chilledwater  0.0
# 31      chilledwater  0.0
# 32      chilledwater  0.0
# 33      chilledwater  0.0
# 34      chilledwater  0.0
# ...              ...  ...
# 399995  chilledwater  0.0
# 399996   electricity  0.0
# 399997  chilledwater  0.0
# 399998   electricity  0.0
# 399999  chilledwater  0.0
#
# [175466 rows x 6 columns]

# %%
sample['energy_perfeet'] = sample['meter_reading']/sample['square_feet']
sample
# Out:
#         meter_reading  square_feet  air_temperature          primary_use  \
# 0           1857.2600       121074             12.8            Education
# 1           1097.4700        61904             12.8            Education
# 2            337.6830        16726             12.8               Office
# 3           1266.3100       200933             12.8  Lodging/residential
# 4            337.6830        21657             12.8            Education
# ...               ...          ...              ...                  ...
# 399995        31.3703         9703             27.2               Office
# 399996        68.7800       102856             27.2      Public services
# 399997       206.7910       102856             27.2      Public services
# 399998        67.2300        60086             27.2  Lodging/residential
# 399999        97.8036        60086             27.2  Lodging/residential
#
#                meter  HDD  energy_perfeet
# 0       chilledwater  5.2        0.015340
# 1       chilledwater  5.2        0.017729
# 2       chilledwater  5.2        0.020189
# 3       chilledwater  5.2        0.006302
# 4       chilledwater  5.2        0.015592
# ...              ...  ...             ...
# 399995  chilledwater  0.0        0.003233
# 399996   electricity  0.0        0.000669
# 399997  chilledwater  0.0        0.002010
# 399998   electricity  0.0        0.001119
# 399999  chilledwater  0.0        0.001628
#
# [400000 rows x 7 columns]

# %%
HDD(4)
# Out:
# 14

# %%
sns.lmplot(x='HDD',y='energy_perfeet',data=sample)

# %%
k = sns.relplot(x="HDD", y="energy_perfeet",
                 col="primary_use",
                 row='meter',
                 kind="scatter", data=sample)

# %%
k = sns.relplot(x="air_temperature", y="meter_reading",
                 col="primary_use",
                 kind="scatter", data=sample)

# %%
k = sns.relplot(x="air_temperature", y="meter_reading",
                 col="meter",
                 row = "primary_use",
                 kind="scatter", data=sample)
