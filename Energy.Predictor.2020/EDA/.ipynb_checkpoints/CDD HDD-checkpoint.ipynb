# %%
import pandas as pd
import seaborn as sns
import gc
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
test = pd.read_csv("../data/df_samp.csv")

# %%
sample = test[['meter_reading','square_feet','air_temperature','primary_use','meter']].head(100000)

# %%
sample.shape
# Out:
# (100000, 5)

# %%
sample.head()
# Out:
#    meter_reading  square_feet  air_temperature          primary_use  \
# 0        886.418        76257             12.8            Education
# 1       1266.310       200933             12.8  Lodging/residential
# 2       1477.360        76257             12.2            Education
# 3       2152.730       200933             12.2  Lodging/residential
# 4       1603.990        76257             12.8            Education
#
#           meter
# 0  chilledwater
# 1  chilledwater
# 2  chilledwater
# 3  chilledwater
# 4  chilledwater

# %%
sns.lmplot(x='air_temperature',y='meter_reading',data=sample)

# %%
k = sns.relplot(x="air_temperature", y="meter_reading",
                 col="primary_use",
                 row='meter',
                 kind="scatter", data=sample)

# %%
def HDD(x):
    dd = x-5
    if dd>0:
        return dd
    else:
        return 0

# %%
sample['HDD']=sample['air_temperature'].apply(lambda x: HDD(x))
sample[sample.HDD==0]
# Out:
#        meter_reading  square_feet  air_temperature          primary_use  \
# 11724      1435.1500        76257              5.0            Education
# 11725       844.2070       200933              5.0  Lodging/residential
# 13622        23.3036        50623              3.8            Education
# 13623       175.1840        97532              3.8            Education
# 13624       219.2040        91149              3.8            Education
# ...              ...          ...              ...                  ...
# 99995       442.6000        91149             -1.2            Education
# 99996       354.6380        91149             -1.2            Education
# 99997        20.2000        38319             -1.2            Education
# 99998        68.0000       102957             -1.2  Lodging/residential
# 99999        62.7000        49589             -1.2  Lodging/residential
#
#               meter  HDD
# 11724  chilledwater  0.0
# 11725  chilledwater  0.0
# 13622   electricity  0.0
# 13623   electricity  0.0
# 13624   electricity  0.0
# ...             ...  ...
# 99995   electricity  0.0
# 99996      hotwater  0.0
# 99997   electricity  0.0
# 99998   electricity  0.0
# 99999   electricity  0.0
#
# [11609 rows x 6 columns]

# %%
sample['energy_perfeet'] = sample['meter_reading']/sample['square_feet']
sample
# Out:
#        meter_reading  square_feet  air_temperature          primary_use  \
# 0            886.418        76257             12.8            Education
# 1           1266.310       200933             12.8  Lodging/residential
# 2           1477.360        76257             12.2            Education
# 3           2152.730       200933             12.2  Lodging/residential
# 4           1603.990        76257             12.8            Education
# ...              ...          ...              ...                  ...
# 99995        442.600        91149             -1.2            Education
# 99996        354.638        91149             -1.2            Education
# 99997         20.200        38319             -1.2            Education
# 99998         68.000       102957             -1.2  Lodging/residential
# 99999         62.700        49589             -1.2  Lodging/residential
#
#               meter  HDD  energy_perfeet
# 0      chilledwater  7.8        0.011624
# 1      chilledwater  7.8        0.006302
# 2      chilledwater  7.2        0.019373
# 3      chilledwater  7.2        0.010714
# 4      chilledwater  7.8        0.021034
# ...             ...  ...             ...
# 99995   electricity  0.0        0.004856
# 99996      hotwater  0.0        0.003891
# 99997   electricity  0.0        0.000527
# 99998   electricity  0.0        0.000660
# 99999   electricity  0.0        0.001264
#
# [100000 rows x 7 columns]

# %%
HDD(4)
# Out:
# 0

# %%
sns.lmplot(x='HDD',y='energy_perfeet',data=sample)

# %%
k = sns.relplot(x="HDD", y="energy_perfeet",
                 col="primary_use",
                 row='meter',
                 kind="scatter", data=sample)

# %%
ax = sns.lmplot(x='HDD_perfeet',y='meter_reading',data=sample)
ax.set(xlim=(0, .0002))

# %%
ax = sns.relplot(x="HDD_perfeet", y="meter_reading",
                 col="primary_use",
                 row='meter',
                 kind="scatter", data=sample)

ax.set(xlim=(0, .0002))
